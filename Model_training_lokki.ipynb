# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaypt7/Storytelling_AI/blob/main/Model_training_lokki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dreambooth Training - Story AI

# %% [markdown]
# This !wegt downloads this file into our current working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -q https://github.com/akshaypt7/Storytelling_AI/raw/main/train_dreambooth.py

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py

# %%
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 182 kB 4.1 MB/s
#   Building wheel for diffusers (PEP 517) ... done

# %% [markdown]
#  Triton makes it possible to reach peak hardware performance with relatively little effort

# %%
# %pip install -q -U --pre triton
# Out:
#      |████████████████████████████████| 18.7 MB 4.3 MB/s

# %% [markdown]
#  Accelerate is a library that enables the same PyTorch code to be run across any distributed configuration by adding just four lines of code! In short, training and inference at scale made simple, efficient and adaptable
#
#  transformers - Transformers provides APIs and tools to easily download and train state-of-the-art pretrained models.
#
# ftfy - The goal of ftfy is to take in bad Unicode and output good Unicode, for use in your Unicode-aware code.

# %% [markdown]
# Bitsandbytes -  is a lightweight wrapper around CUDA custom functions, in particular 8-bit optimizers and quantization functions.
#
# Gradio - is the fastest way to demo your machine learning model with a friendly web interface so that anyone can use it, anywhere!
#
# natsort. - Simple yet flexible natural sorting in Python.

# %%
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio natsort
# Out:
#      |████████████████████████████████| 143 kB 4.2 MB/s
#      |████████████████████████████████| 5.8 MB 31.5 MB/s
#      |████████████████████████████████| 53 kB 2.0 MB/s
#      |████████████████████████████████| 62.5 MB 49 kB/s
#      |████████████████████████████████| 11.6 MB 66.0 MB/s
#      |████████████████████████████████| 7.6 MB 56.4 MB/s
#      |████████████████████████████████| 54 kB 3.0 MB/s
#      |████████████████████████████████| 56 kB 63 kB/s
#      |████████████████████████████████| 213 kB 63.8 MB/s
#      |████████████████████████████████| 84 kB 4.2 MB/s
#      |████████████████████████████████| 278 kB 87.4 MB/s
#      |████████████████████████████████| 106 kB 84.5 MB/s
#      |████████████████████████████████| 84 kB 3.9 MB/s
#      |████████████████████████████████| 55 kB 1.8 MB/s
#      |████████████████████████████████| 2.3 MB 85.2 MB/s
#      |████████████████████████████████| 64 kB 3.5 MB/s
#      |████████████████████████████████| 80 kB 10.5 MB/s
#      |████████████████████████████████| 68 kB 8.2 MB/s
#      |████████████████████████████████| 68 kB 7.8 MB/s
#      |████████████████████████████████| 68 kB 8.6 MB/s
#      |████████████████████████████████| 68 kB 7.9 MB/s
#      |████████████████████████████████| 46 kB 4.4 MB/s
#      |████████████████████████████████| 4.0 MB 54.9 MB/s
#      |████████████████████████████████| 593 kB 91.0 MB/s
#      |████████████████████████████████| 856 kB 77.7 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %% [markdown]
# ## Login to HuggingFace 🤗

# %%
# !mkdir -p ~/.huggingface # creating a new folder called huggingface?

# %%
HUGGINGFACE_TOKEN = "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"

# %%
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token # copying the token to the huggingface folder

# %% [markdown]
# ## Install xformers from precompiled wheel.

# %% [markdown]
# xformers is a pytorch based library which hosts flexible Transformers parts.They are interoperable and optimized building blocks, which can be optionally be combined to create some state of the art models

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xformers
#   Cloning https://github.com/facebookresearch/xformers (to revision 1d31a3a) to /tmp/pip-install-86w12m7e/xformers_cd4445e06d294dc9a1a1009d2a114924
#   Running command git clone -q https://github.com/facebookresearch/xformers /tmp/pip-install-86w12m7e/xformers_cd4445e06d294dc9a1a1009d2a114924
#   WARNING: Did not find branch or tag '1d31a3a', assuming revision or ref.
#   Running command git checkout -q 1d31a3a
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.8/dist-packages (from xformers) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xformers) (1.21.6)
# Collecting pyre-extensions==0.0.23
#   Downloading pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from pyre-extensions==0.0.23->xformers) (4.1.1)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: xformers
#   Building wheel for xformers (setup.py) ... done
#   Created wheel for xformers: filename=xformers-0.0.14.dev0-cp38-cp38-linux_x86_64.whl size=91631355 sha256=3b6d675379eb74998ccd487e200d8c6cb8936f91391e45783fd268578d707788
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ejgnwv0e/wheels/5f/3f/8d/a1f7db4c46304e4c83f3ce87dd959d5fcc266b04b9095a737c
# Successfully built xformers
# Installing collected packages: mypy-extensions, typing-inspect, pyre-extensions, xformers
# Successfully installed mypy-extensions-0.4.3 pyre-extensions-0.0.23 typing-inspect-0.8.0 xformers-0.0.14.dev0

# %% [markdown]
# ## Settings and run

# %%
MODEL_NAME = "CompVis/stable-diffusion-v1-4"
OUTPUT_DIR = '/content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_model_output/Output/weights'

# !mkdir -p $OUTPUT_DIR
print(f"[*] Weights will be saved at {OUTPUT_DIR}")
# Out:
# [*] Weights will be saved at /content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_model_output/Output/weights

# %% [markdown]
# ## Start Training

# %% [markdown]
# The **instance prompt** is basically anything that you want to custom train, your photo, product..etc.., you can name it anything..better to name it relative the custom dataset

# %% [markdown]
# **Class prompt**, is what is the category the instance prompt belongs to. If you use your photo it would be men or person.

# %% [markdown]
# **Instance_data_dir** - Is where we store the images, which we want to custom train. This is the images used for finetuning by dreambooth.

# %% [markdown]
# **class_data_dir** - Is where we store the images of the class - person, these images are downloaded by the programme it self, but when we are building our final model, we can store these images

# %% [markdown]
# My asssumption is we will be training the stable diffusion model, and finetuning it with both the custom images and class images.

# %%
concepts_list = [
    {
        "instance_prompt":      "lokki",
        "class_prompt":         "dog",
        "instance_data_dir":    "/content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_images",
        "class_data_dir":       "/content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_class_dog_images"
    }
]

# %%
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=15 \
  --sample_batch_size=4 \
  --max_train_steps=1 \
  --save_interval=10000 \
  --save_sample_prompt="photo of lokki person" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `2` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 918kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 713kB/s]
# Downloading: 100% 472/472 [00:00<00:00, 406kB/s]
# Downloading: 100% 788/788 [00:00<00:00, 712kB/s]
# Downloading: 100% 572/572 [00:00<00:00, 512kB/s]
# Downloading: 100% 246M/246M [00:03<00:00, 74.9MB/s]
# Downloading: 100% 167M/167M [00:02<00:00, 78.2MB/s]
# Downloading: 100% 550/550 [00:00<00:00, 447kB/s]
# Downloading: 100% 1.72G/1.72G [00:22<00:00, 77.5MB/s]
# Downloading: 100% 772/772 [00:00<00:00, 699kB/s]
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   warnings.warn(warning + message, FutureWarning)
# Downloading: 100% 313/313 [00:00<00:00, 301kB/s]
# Caching latents: 100% 36/36 [00:41<00:00,  1.15s/it]
# Steps: 100% 1/1 [00:10<00:00, 10.03s/it, loss=0.0543, lr=1e-6]
# Downloading:   0% 0.00/335M [00:00<?, ?B/s]
# Downloading:   3% 8.71M/335M [00:00<00:03, 87.1MB/s]
# Downloading:   5% 17.4M/335M [00:00<00:03, 81.3MB/s]
# Downloading:   8% 25.6M/335M [00:00<00:03, 81.3MB/s]
# Downloading:  10% 33.7M/335M [00:00<00:04, 74.6MB/s]
# Downloading:  12% 41.6M/335M [00:00<00:03, 75.9MB/s]
# Downloading:  15% 50.4M/335M [00:00<00:03, 80.1MB/s]
# Downloading:  17% 58.5M/335M [00:00<00:03, 79.6MB/s]
# Downloading:  20% 66.9M/335M [00:00<00:03, 80.9MB/s]
# Downloading:  23% 75.5M/335M [00:00<00:03, 82.1MB/s]
# Downloading:  25% 83.8M/335M [00:01<00:03, 80.8MB/s]
# Downloading:  27% 91.9M/335M [00:01<00:03, 78.1MB/s]
# Downloading:  30% 99.7M/335M [00:01<00:03, 77.9MB/s]
# Downloading:  32% 108M/335M [00:01<00:02, 76.3MB/s]
# Downloading:  34% 115M/335M [00:01<00:03, 70.4MB/s]
# Downloading:  37% 123M/335M [00:01<00:02, 71.5MB/s]
# Downloading:  39% 131M/335M [00:01<00:02, 76.1MB/s]
# Downloading:  42% 140M/335M [00:01<00:02, 78.7MB/s]
# Downloading:  44% 149M/335M [00:01<00:02, 80.9MB/s]
# Downloading:  47% 157M/335M [00:01<00:02, 81.0MB/s]
# Downloading:  50% 166M/335M [00:02<00:02, 83.8MB/s]
# Downloading:  52% 175M/335M [00:02<00:01, 85.6MB/s]
# Downloading:  55% 183M/335M [00:02<00:01, 85.6MB/s]
# Downloading:  57% 192M/335M [00:02<00:01, 86.8MB/s]
# Downloading:  60% 201M/335M [00:02<00:01, 87.3MB/s]
# Downloading:  63% 210M/335M [00:02<00:01, 86.7MB/s]
# Downloading:  65% 219M/335M [00:02<00:01, 81.3MB/s]
# Downloading:  68% 227M/335M [00:02<00:01, 82.9MB/s]
# Downloading:  70% 236M/335M [00:02<00:01, 82.5MB/s]
# Downloading:  73% 244M/335M [00:03<00:01, 84.0MB/s]
# Downloading:  76% 253M/335M [00:03<00:00, 83.1MB/s]
# Downloading:  78% 261M/335M [00:03<00:00, 82.8MB/s]
# Downloading:  80% 269M/335M [00:03<00:00, 79.6MB/s]
# Downloading:  83% 277M/335M [00:03<00:00, 72.6MB/s]
# Downloading:  85% 286M/335M [00:03<00:00, 76.5MB/s]
# Downloading:  88% 294M/335M [00:03<00:00, 76.4MB/s]
# Downloading:  90% 302M/335M [00:03<00:00, 77.6MB/s]
# Downloading:  93% 310M/335M [00:03<00:00, 79.8MB/s]
# Downloading:  95% 319M/335M [00:03<00:00, 82.0MB/s]
# Downloading: 100% 335M/335M [00:04<00:00, 80.3MB/s]
#
# Downloading: 100% 547/547 [00:00<00:00, 513kB/s]
#
# Downloading: 100% 543/543 [00:00<00:00, 512kB/s]
#
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
#
# Downloading: 100% 342/342 [00:00<00:00, 309kB/s]
#
# Fetching 16 files:   6% 1/16 [00:01<00:22,  1.52s/it]
#
# Downloading: 100% 4.63k/4.63k [00:00<00:00, 3.84MB/s]
#
# Fetching 16 files:  19% 3/16 [00:03<00:12,  1.04it/s]
#
# Downloading:   0% 0.00/608M [00:00<?, ?B/s]
#
# Downloading:   0% 2.05k/608M [00:00<14:15:20, 11.8kB/s]
#
# Downloading:   0% 52.2k/608M [00:00<57:54, 175kB/s]
#
# Downloading:   0% 122k/608M [00:00<36:33, 277kB/s]
#
# Downloading:   0% 296k/608M [00:00<17:57, 564kB/s]
#
# Downloading:   0% 609k/608M [00:00<10:02, 1.01MB/s]
#
# Downloading:   0% 1.24M/608M [00:01<05:20, 1.89MB/s]
#
# Downloading:   0% 2.52M/608M [00:01<02:44, 3.68MB/s]
#
# Downloading:   1% 5.09M/608M [00:01<01:23, 7.23MB/s]
#
# Downloading:   2% 9.17M/608M [00:01<00:49, 12.2MB/s]
#
# Downloading:   2% 13.1M/608M [00:01<00:38, 15.3MB/s]
#
# Downloading:   3% 17.1M/608M [00:01<00:33, 17.6MB/s]
#
# Downloading:   3% 21.2M/608M [00:02<00:30, 19.1MB/s]
#
# Downloading:   4% 25.2M/608M [00:02<00:28, 20.1MB/s]
#
# Downloading:   5% 29.3M/608M [00:02<00:27, 21.0MB/s]
#
# Downloading:   5% 32.0M/608M [00:02<00:26, 21.8MB/s]
#
# Downloading:   6% 35.6M/608M [00:02<00:23, 24.1MB/s]
#
# Downloading:   6% 38.1M/608M [00:02<00:25, 22.2MB/s]
#
# Downloading:   7% 41.3M/608M [00:02<00:26, 21.0MB/s]
#
# Downloading:   7% 45.3M/608M [00:03<00:26, 21.6MB/s]
#
# Downloading:   8% 49.3M/608M [00:03<00:25, 21.6MB/s]
#
# Downloading:   9% 53.3M/608M [00:03<00:25, 22.0MB/s]
#
# Downloading:   9% 57.4M/608M [00:03<00:24, 22.2MB/s]
#
# Downloading:  10% 60.9M/608M [00:03<00:25, 21.7MB/s]
#
# Downloading:  11% 64.8M/608M [00:04<00:24, 21.8MB/s]
#
# Downloading:  11% 68.8M/608M [00:04<00:24, 22.0MB/s]
#
# Downloading:  12% 72.8M/608M [00:04<00:24, 22.2MB/s]
#
# Downloading:  13% 76.8M/608M [00:04<00:23, 22.2MB/s]
#
# Downloading:  13% 80.8M/608M [00:04<00:23, 22.3MB/s]
#
# Downloading:  14% 84.5M/608M [00:04<00:20, 25.1MB/s]
#
# Downloading:  14% 87.1M/608M [00:05<00:21, 23.9MB/s]
#
# Downloading:  15% 89.6M/608M [00:05<00:23, 22.0MB/s]
#
# Downloading:  15% 91.9M/608M [00:05<00:26, 19.3MB/s]
#
# Downloading:  16% 95.7M/608M [00:05<00:25, 20.1MB/s]
#
# Downloading:  16% 99.7M/608M [00:05<00:24, 20.9MB/s]
#
# Downloading:  17% 104M/608M [00:05<00:23, 21.6MB/s]
#
# Downloading:  18% 108M/608M [00:06<00:22, 22.0MB/s]
#
# Downloading:  18% 112M/608M [00:06<00:22, 21.9MB/s]
#
# Downloading:  19% 116M/608M [00:06<00:22, 22.1MB/s]
#
# Downloading:  20% 120M/608M [00:06<00:21, 22.4MB/s]
#
# Downloading:  20% 124M/608M [00:06<00:21, 22.3MB/s]
#
# Downloading:  21% 127M/608M [00:06<00:22, 21.8MB/s]
#
# Downloading:  21% 131M/608M [00:07<00:20, 23.4MB/s]
#
# Downloading:  22% 134M/608M [00:07<00:19, 24.1MB/s]
#
# Downloading:  22% 136M/608M [00:07<00:21, 22.2MB/s]
#
# Downloading:  23% 139M/608M [00:07<00:21, 21.4MB/s]
#
# Downloading:  24% 143M/608M [00:07<00:21, 21.5MB/s]
#
# Downloading:  24% 147M/608M [00:07<00:21, 21.2MB/s]
#
# Downloading:  25% 151M/608M [00:07<00:21, 21.6MB/s]
#
# Downloading:  26% 155M/608M [00:08<00:20, 21.9MB/s]
#
# Downloading:  26% 159M/608M [00:08<00:20, 21.7MB/s]
#
# Downloading:  27% 163M/608M [00:08<00:20, 21.7MB/s]
#
# Downloading:  27% 167M/608M [00:08<00:20, 22.0MB/s]
#
# Downloading:  28% 171M/608M [00:08<00:19, 22.0MB/s]
#
# Downloading:  29% 175M/608M [00:09<00:19, 22.3MB/s]
#
# Downloading:  29% 179M/608M [00:09<00:19, 22.4MB/s]
#
# Downloading:  30% 183M/608M [00:09<00:18, 22.5MB/s]
#
# Downloading:  31% 187M/608M [00:09<00:18, 22.6MB/s]
#
# Downloading:  31% 191M/608M [00:09<00:18, 22.5MB/s]
#
# Downloading:  32% 195M/608M [00:09<00:18, 22.5MB/s]
#
# Downloading:  33% 199M/608M [00:10<00:18, 22.7MB/s]
#
# Downloading:  33% 203M/608M [00:10<00:17, 22.9MB/s]
#
# Downloading:  34% 207M/608M [00:10<00:17, 22.6MB/s]
#
# Downloading:  35% 210M/608M [00:10<00:16, 24.0MB/s]
#
# Downloading:  35% 213M/608M [00:10<00:16, 24.3MB/s]
#
# Downloading:  35% 215M/608M [00:10<00:17, 22.2MB/s]
#
# Downloading:  36% 219M/608M [00:11<00:17, 21.6MB/s]
#
# Downloading:  37% 223M/608M [00:11<00:17, 21.9MB/s]
#
# Downloading:  37% 227M/608M [00:11<00:17, 21.6MB/s]
#
# Downloading:  38% 231M/608M [00:11<00:17, 21.8MB/s]
#
# Downloading:  39% 235M/608M [00:11<00:17, 22.0MB/s]
#
# Downloading:  39% 239M/608M [00:11<00:16, 22.2MB/s]
#
# Downloading:  40% 243M/608M [00:12<00:16, 22.2MB/s]
#
# Downloading:  41% 247M/608M [00:12<00:16, 22.5MB/s]
#
# Downloading:  41% 251M/608M [00:12<00:15, 22.8MB/s]
#
# Downloading:  42% 255M/608M [00:12<00:15, 22.3MB/s]
#
# Downloading:  43% 259M/608M [00:12<00:15, 22.7MB/s]
#
# Downloading:  43% 261M/608M [00:12<00:15, 22.7MB/s]
#
# Downloading:  43% 264M/608M [00:12<00:14, 24.1MB/s]
#
# Downloading:  44% 267M/608M [00:13<00:15, 22.0MB/s]
#
# Downloading:  45% 271M/608M [00:13<00:15, 22.0MB/s]
#
# Downloading:  45% 275M/608M [00:13<00:14, 22.3MB/s]
#
# Downloading:  46% 279M/608M [00:13<00:14, 22.2MB/s]
#
# Downloading:  46% 283M/608M [00:13<00:14, 22.3MB/s]
#
# Downloading:  47% 287M/608M [00:14<00:14, 22.5MB/s]
#
# Downloading:  48% 291M/608M [00:14<00:14, 22.4MB/s]
#
# Downloading:  48% 295M/608M [00:14<00:13, 22.5MB/s]
#
# Downloading:  49% 299M/608M [00:14<00:13, 22.6MB/s]
#
# Downloading:  50% 303M/608M [00:14<00:13, 22.6MB/s]
#
# Downloading:  50% 307M/608M [00:14<00:13, 22.7MB/s]
#
# Downloading:  51% 311M/608M [00:15<00:13, 22.6MB/s]
#
# Downloading:  52% 313M/608M [00:15<00:13, 22.6MB/s]
#
# Downloading:  52% 317M/608M [00:15<00:12, 24.2MB/s]
#
# Downloading:  52% 319M/608M [00:15<00:13, 22.2MB/s]
#
# Downloading:  53% 322M/608M [00:15<00:13, 21.2MB/s]
#
# Downloading:  54% 326M/608M [00:15<00:13, 21.3MB/s]
#
# Downloading:  54% 330M/608M [00:15<00:12, 21.7MB/s]
#
# Downloading:  55% 334M/608M [00:16<00:12, 22.1MB/s]
#
# Downloading:  56% 338M/608M [00:16<00:12, 22.2MB/s]
#
# Downloading:  56% 342M/608M [00:16<00:11, 22.2MB/s]
#
# Downloading:  57% 346M/608M [00:16<00:11, 22.2MB/s]
#
# Downloading:  58% 350M/608M [00:16<00:11, 22.2MB/s]
#
# Downloading:  58% 354M/608M [00:17<00:11, 22.2MB/s]
#
# Downloading:  59% 358M/608M [00:17<00:11, 22.3MB/s]
#
# Downloading:  60% 362M/608M [00:17<00:10, 22.5MB/s]
#
# Downloading:  60% 365M/608M [00:17<00:10, 24.2MB/s]
#
# Downloading:  61% 368M/608M [00:17<00:10, 23.9MB/s]
#
# Downloading:  61% 371M/608M [00:17<00:10, 22.2MB/s]
#
# Downloading:  62% 374M/608M [00:17<00:10, 21.6MB/s]
#
# Downloading:  62% 378M/608M [00:18<00:10, 22.0MB/s]
#
# Downloading:  63% 382M/608M [00:18<00:10, 21.9MB/s]
#
# Downloading:  63% 386M/608M [00:18<00:10, 22.1MB/s]
#
# Downloading:  64% 390M/608M [00:18<00:09, 22.1MB/s]
#
# Downloading:  65% 394M/608M [00:18<00:09, 22.2MB/s]
#
# Downloading:  65% 398M/608M [00:18<00:09, 22.4MB/s]
#
# Downloading:  66% 402M/608M [00:19<00:09, 22.1MB/s]
#
# Downloading:  67% 406M/608M [00:19<00:08, 22.5MB/s]
#
# Downloading:  67% 410M/608M [00:19<00:08, 22.4MB/s]
#
# Downloading:  68% 414M/608M [00:19<00:08, 22.4MB/s]
#
# Downloading:  68% 416M/608M [00:19<00:08, 22.1MB/s]
#
# Downloading:  69% 420M/608M [00:19<00:07, 24.3MB/s]
#
# Downloading:  69% 422M/608M [00:20<00:08, 22.5MB/s]
#
# Downloading:  70% 426M/608M [00:20<00:08, 22.3MB/s]
#
# Downloading:  71% 430M/608M [00:20<00:08, 22.2MB/s]
#
# Downloading:  71% 434M/608M [00:20<00:08, 21.7MB/s]
#
# Downloading:  72% 438M/608M [00:20<00:07, 21.9MB/s]
#
# Downloading:  73% 442M/608M [00:20<00:07, 22.1MB/s]
#
# Downloading:  73% 446M/608M [00:21<00:07, 22.0MB/s]
#
# Downloading:  74% 449M/608M [00:21<00:07, 21.9MB/s]
#
# Downloading:  75% 454M/608M [00:21<00:06, 22.2MB/s]
#
# Downloading:  75% 458M/608M [00:21<00:06, 22.4MB/s]
#
# Downloading:  76% 462M/608M [00:21<00:06, 22.4MB/s]
#
# Downloading:  76% 465M/608M [00:22<00:06, 21.6MB/s]
#
# Downloading:  77% 468M/608M [00:22<00:06, 22.7MB/s]
#
# Downloading:  77% 471M/608M [00:22<00:05, 24.0MB/s]
#
# Downloading:  78% 474M/608M [00:22<00:06, 22.1MB/s]
#
# Downloading:  78% 477M/608M [00:22<00:06, 21.1MB/s]
#
# Downloading:  79% 481M/608M [00:22<00:05, 21.4MB/s]
#
# Downloading:  80% 484M/608M [00:22<00:06, 20.5MB/s]
#
# Downloading:  80% 488M/608M [00:23<00:05, 21.3MB/s]
#
# Downloading:  81% 492M/608M [00:23<00:05, 21.7MB/s]
#
# Downloading:  82% 496M/608M [00:23<00:05, 21.9MB/s]
#
# Downloading:  82% 500M/608M [00:23<00:04, 21.9MB/s]
#
# Downloading:  83% 504M/608M [00:23<00:04, 22.4MB/s]
#
# Downloading:  84% 508M/608M [00:23<00:04, 22.3MB/s]
#
# Downloading:  84% 512M/608M [00:24<00:04, 22.3MB/s]
#
# Downloading:  85% 516M/608M [00:24<00:04, 22.4MB/s]
#
# Downloading:  86% 520M/608M [00:24<00:03, 22.6MB/s]
#
# Downloading:  86% 524M/608M [00:24<00:03, 22.6MB/s]
#
# Downloading:  87% 528M/608M [00:24<00:03, 21.9MB/s]
#
# Downloading:  87% 532M/608M [00:25<00:03, 22.1MB/s]
#
# Downloading:  88% 536M/608M [00:25<00:03, 22.1MB/s]
#
# Downloading:  89% 540M/608M [00:25<00:03, 21.7MB/s]
#
# Downloading:  89% 544M/608M [00:25<00:02, 22.1MB/s]
#
# Downloading:  90% 548M/608M [00:25<00:02, 21.9MB/s]
#
# Downloading:  91% 552M/608M [00:25<00:02, 22.0MB/s]
#
# Downloading:  91% 556M/608M [00:26<00:02, 22.1MB/s]
#
# Downloading:  92% 559M/608M [00:26<00:02, 22.2MB/s]
#
# Downloading:  93% 564M/608M [00:26<00:01, 22.3MB/s]
#
# Downloading:  93% 567M/608M [00:26<00:01, 22.5MB/s]
#
# Downloading:  94% 570M/608M [00:26<00:01, 22.9MB/s]
#
# Downloading:  94% 573M/608M [00:26<00:01, 24.6MB/s]
#
# Downloading:  95% 576M/608M [00:27<00:01, 22.5MB/s]
#
# Downloading:  95% 580M/608M [00:27<00:01, 21.8MB/s]
#
# Downloading:  96% 584M/608M [00:27<00:01, 22.2MB/s]
#
# Downloading:  97% 588M/608M [00:27<00:00, 22.2MB/s]
#
# Downloading:  97% 592M/608M [00:27<00:00, 22.5MB/s]
#
# Downloading:  98% 596M/608M [00:27<00:00, 22.5MB/s]
#
# Downloading:  99% 600M/608M [00:28<00:00, 22.4MB/s]
#
# Downloading:  99% 604M/608M [00:28<00:00, 22.8MB/s]
#
# Downloading: 100% 608M/608M [00:28<00:00, 21.4MB/s]
#
# Fetching 16 files:  25% 4/16 [00:33<02:12, 11.04s/it]
#
# Downloading: 100% 209/209 [00:00<00:00, 190kB/s]
#
# Fetching 16 files:  31% 5/16 [00:34<01:27,  7.91s/it]
#
# Downloading: 100% 209/209 [00:00<00:00, 191kB/s]
#
# Fetching 16 files:  38% 6/16 [00:36<00:58,  5.86s/it]
#
# Downloading: 100% 572/572 [00:00<00:00, 484kB/s]
#
# Fetching 16 files:  44% 7/16 [00:37<00:40,  4.49s/it]
#
# Downloading:   0% 0.00/246M [00:00<?, ?B/s]
#
# Downloading:   4% 9.73M/246M [00:00<00:02, 97.3MB/s]
#
# Downloading:   9% 21.3M/246M [00:00<00:02, 108MB/s]
#
# Downloading:  13% 32.6M/246M [00:00<00:01, 111MB/s]
#
# Downloading:  18% 44.1M/246M [00:00<00:01, 112MB/s]
#
# Downloading:  23% 55.6M/246M [00:00<00:01, 113MB/s]
#
# Downloading:  27% 67.0M/246M [00:00<00:01, 113MB/s]
#
# Downloading:  32% 78.4M/246M [00:00<00:01, 112MB/s]
#
# Downloading:  37% 89.9M/246M [00:00<00:01, 113MB/s]
#
# Downloading:  41% 101M/246M [00:00<00:01, 114MB/s]
#
# Downloading:  46% 113M/246M [00:01<00:01, 115MB/s]
#
# Downloading:  51% 125M/246M [00:01<00:01, 114MB/s]
#
# Downloading:  55% 136M/246M [00:01<00:00, 115MB/s]
#
# Downloading:  60% 148M/246M [00:01<00:00, 115MB/s]
#
# Downloading:  65% 159M/246M [00:01<00:00, 115MB/s]
#
# Downloading:  70% 171M/246M [00:01<00:00, 116MB/s]
#
# Downloading:  74% 183M/246M [00:01<00:00, 115MB/s]
#
# Downloading:  79% 194M/246M [00:01<00:00, 114MB/s]
#
# Downloading:  84% 206M/246M [00:01<00:00, 115MB/s]
#
# Downloading:  89% 218M/246M [00:01<00:00, 116MB/s]
#
# Downloading:  93% 230M/246M [00:02<00:00, 116MB/s]
#
# Downloading: 100% 246M/246M [00:02<00:00, 112MB/s]
#
# Fetching 16 files:  50% 8/16 [00:40<00:32,  4.04s/it]
#
# Downloading:   0% 0.00/525k [00:00<?, ?B/s]
#
# Downloading:   2% 12.3k/525k [00:00<00:07, 67.5kB/s]
#
# Downloading:   8% 42.0k/525k [00:00<00:03, 124kB/s]
#
# Downloading:  16% 86.0k/525k [00:00<00:02, 177kB/s]
#
# Downloading:  35% 184k/525k [00:00<00:01, 320kB/s]
#
# Downloading: 100% 525k/525k [00:00<00:00, 573kB/s]
#
# Fetching 16 files:  56% 9/16 [00:43<00:24,  3.55s/it]
#
# Downloading: 100% 472/472 [00:00<00:00, 422kB/s]
#
# Fetching 16 files:  62% 10/16 [00:44<00:17,  2.95s/it]
#
# Downloading: 100% 788/788 [00:00<00:00, 689kB/s]
#
# Fetching 16 files:  69% 11/16 [00:46<00:12,  2.51s/it]
#
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading:   1% 12.3k/1.06M [00:00<00:16, 64.0kB/s]
#
# Downloading:   3% 32.8k/1.06M [00:00<00:11, 88.9kB/s]
#
# Downloading:   8% 81.9k/1.06M [00:00<00:05, 165kB/s]
#
# Downloading:  19% 197k/1.06M [00:00<00:02, 335kB/s]
#
# Downloading:  40% 426k/1.06M [00:00<00:00, 642kB/s]
#
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 914kB/s]
#
# Fetching 16 files: 100% 16/16 [00:49<00:00,  3.07s/it]
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:12<00:37, 12.58s/it]
# Generating samples:  50% 2/4 [00:21<00:20, 10.46s/it]
# Generating samples:  75% 3/4 [00:30<00:09,  9.84s/it]
# Generating samples: 100% 4/4 [00:39<00:00, 10.00s/it]
# [*] Weights saved at /content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_model_output/Output/weights/1
# Steps: 100% 1/1 [02:06<00:00, 126.14s/it, loss=0.0543, lr=1e-6]

# %% [markdown]
# ## Inference

# %%
WEIGHTS_DIR = "" # pass this empty if you need to get a new model
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/AI_5/Stable_diffusion/Lokki/lokki_model_output/Output/weights/4000

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)
pipe = StableDiffusionPipeline.from_pretrained(model_path, scheduler=scheduler, safety_checker=None, torch_dtype=torch.float16).to("cuda")

g_cuda = None
# Out:
# /usr/local/lib/python3.8/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)

# %% [markdown]
# breathtaking watercolor painting of massive green labrador retrievers with shaggy green fur leaping through a lush sea of grass, fantasy art by greg rutkowski, loish, rhads, ferdinand knab, makoto shinkai and lois van baarle, ilya kuvshinov, rossdraws, tom bagshaw, global illumination, radiant light, detailed and intricate environment

# %%
#@title Run for generating images.

prompt = "Lokki dog playing in the garden, leaping through a lush sea of grass, fantasy art by greg rutkowski, loish, rhads, ferdinand knab, makoto shinkai and lois van baarle, ilya kuvshinov, rossdraws, tom bagshaw, global illumination, radiant light, detailed and intricate environment" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 4.7 #@param {type:"number"}
num_inference_steps = 60 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD100303D30>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD1002368B0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD1002365E0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD1001E1CD0>
