# %% [markdown]
# ## Dreambooth Training - Story AI

# %% [markdown]
# This !wegt downloads this file into our current working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -q https://github.com/akshaypt7/Storytelling_AI/raw/main/train_dreambooth.py

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py

# %%
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 182 kB 4.1 MB/s
#   Building wheel for diffusers (PEP 517) ... done

# %% [markdown]
#  Triton makes it possible to reach peak hardware performance with relatively little effort

# %%
# %pip install -q -U --pre triton
# Out:
#      |████████████████████████████████| 18.7 MB 3.8 MB/s

# %% [markdown]
#  Accelerate is a library that enables the same PyTorch code to be run across any distributed configuration by adding just four lines of code! In short, training and inference at scale made simple, efficient and adaptable
#
#  transformers - Transformers provides APIs and tools to easily download and train state-of-the-art pretrained models.
#
# ftfy - The goal of ftfy is to take in bad Unicode and output good Unicode, for use in your Unicode-aware code.

# %% [markdown]
# Bitsandbytes -  is a lightweight wrapper around CUDA custom functions, in particular 8-bit optimizers and quantization functions.
#
# Gradio - is the fastest way to demo your machine learning model with a friendly web interface so that anyone can use it, anywhere!
#
# natsort. - Simple yet flexible natural sorting in Python.

# %%
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio natsort
# Out:
#      |████████████████████████████████| 143 kB 4.3 MB/s
#      |████████████████████████████████| 5.8 MB 50.7 MB/s
#      |████████████████████████████████| 53 kB 1.7 MB/s
#      |████████████████████████████████| 62.5 MB 1.2 MB/s
#      |████████████████████████████████| 11.6 MB 69.9 MB/s
#      |████████████████████████████████| 7.6 MB 70.6 MB/s
#      |████████████████████████████████| 56 kB 5.2 MB/s
#      |████████████████████████████████| 84 kB 3.9 MB/s
#      |████████████████████████████████| 106 kB 51.0 MB/s
#      |████████████████████████████████| 54 kB 3.5 MB/s
#      |████████████████████████████████| 213 kB 102.9 MB/s
#      |████████████████████████████████| 2.3 MB 69.1 MB/s
#      |████████████████████████████████| 84 kB 3.7 MB/s
#      |████████████████████████████████| 278 kB 70.8 MB/s
#      |████████████████████████████████| 55 kB 4.1 MB/s
#      |████████████████████████████████| 64 kB 3.3 MB/s
#      |████████████████████████████████| 80 kB 10.5 MB/s
#      |████████████████████████████████| 68 kB 7.2 MB/s
#      |████████████████████████████████| 68 kB 7.2 MB/s
#      |████████████████████████████████| 68 kB 7.2 MB/s
#      |████████████████████████████████| 68 kB 7.6 MB/s
#      |████████████████████████████████| 46 kB 4.5 MB/s
#      |████████████████████████████████| 4.0 MB 58.8 MB/s
#      |████████████████████████████████| 593 kB 92.3 MB/s
#      |████████████████████████████████| 856 kB 69.3 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %% [markdown]
# ## Login to HuggingFace 🤗

# %%
# !mkdir -p ~/.huggingface # creating a new folder called huggingface?

# %%
HUGGINGFACE_TOKEN = "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"

# %%
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token # copying the token to the huggingface folder

# %% [markdown]
# ## Install xformers from precompiled wheel.

# %% [markdown]
# xformers is a pytorch based library which hosts flexible Transformers parts.They are interoperable and optimized building blocks, which can be optionally be combined to create some state of the art models

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
# ERROR: xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl is not a supported wheel on this platform.

# %% [markdown]
# ## Settings and run

# %%
MODEL_NAME = "CompVis/stable-diffusion-v1-4"
OUTPUT_DIR = '/content/drive/MyDrive/AI_5/Stable_diffusion/akshay_model/Output/weights'

# !mkdir -p $OUTPUT_DIR
print(f"[*] Weights will be saved at {OUTPUT_DIR}")
# Out:
# [*] Weights will be saved at /content/drive/MyDrive/AI_5/Stable_diffusion/akshay_model/Output/weights

# %% [markdown]
# ## Start Training

# %% [markdown]
# The **instance prompt** is basically anything that you want to custom train, your photo, product..etc.., you can name it anything..better to name it relative the custom dataset

# %% [markdown]
# **Class prompt**, is what is the category the instance prompt belongs to. If you use your photo it would be men or person.

# %% [markdown]
# **Instance_data_dir** - Is where we store the images, which we want to custom train. This is the images used for finetuning by dreambooth.

# %% [markdown]
# **class_data_dir** - Is where we store the images of the class - person, these images are downloaded by the programme it self, but when we are building our final model, we can store these images

# %% [markdown]
# My asssumption is we will be training the stable diffusion model, and finetuning it with both the custom images and class images.

# %%
concepts_list = [
    {
        "instance_prompt":      "akshay",
        "class_prompt":         "person",
        "instance_data_dir":    "/content/drive/MyDrive/AI_5/Stable_diffusion/akshay_input",
        "class_data_dir":       "/content/drive/MyDrive/AI_5/Stable_diffusion/person_images"
    }
]

# %%
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=15 \
  --sample_batch_size=4 \
  --max_train_steps=4000 \
  --save_interval=10000 \
  --save_sample_prompt="photo of akshay person" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `2` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 1.06M/1.06M [00:00<00:00, 9.52MB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 4.64MB/s]
# Downloading: 100% 472/472 [00:00<00:00, 658kB/s]
# Downloading: 100% 788/788 [00:00<00:00, 1.17MB/s]
# Downloading: 100% 572/572 [00:00<00:00, 732kB/s]
# Downloading: 100% 246M/246M [00:04<00:00, 56.4MB/s]
# Downloading: 100% 167M/167M [00:03<00:00, 51.3MB/s]
# Downloading: 100% 550/550 [00:00<00:00, 748kB/s]
# Downloading: 100% 1.72G/1.72G [00:33<00:00, 51.6MB/s]
# Downloading: 100% 772/772 [00:00<00:00, 1.12MB/s]
# /usr/local/lib/python3.7/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   warnings.warn(warning + message, FutureWarning)
# Downloading: 100% 313/313 [00:00<00:00, 428kB/s]
# Caching latents: 100% 39/39 [00:21<00:00,  1.84it/s]
# Steps: 100% 4000/4000 [1:05:03<00:00,  1.03it/s, loss=0.269, lr=1e-6]
# Downloading:   0% 0.00/335M [00:00<?, ?B/s]
# Downloading:   0% 356k/335M [00:00<01:35, 3.50MB/s]
# Downloading:   0% 867k/335M [00:00<01:15, 4.44MB/s]
# Downloading:   0% 1.50M/335M [00:00<01:02, 5.31MB/s]
# Downloading:   1% 2.31M/335M [00:00<00:52, 6.36MB/s]
# Downloading:   1% 3.39M/335M [00:00<00:41, 7.92MB/s]
# Downloading:   1% 4.80M/335M [00:00<00:33, 9.95MB/s]
# Downloading:   2% 6.55M/335M [00:00<00:26, 12.4MB/s]
# Downloading:   3% 8.81M/335M [00:00<00:20, 15.6MB/s]
# Downloading:   4% 11.8M/335M [00:00<00:16, 19.9MB/s]
# Downloading:   5% 15.5M/335M [00:01<00:12, 25.2MB/s]
# Downloading:   6% 20.3M/335M [00:01<00:09, 32.3MB/s]
# Downloading:   8% 26.5M/335M [00:01<00:07, 41.1MB/s]
# Downloading:  10% 33.9M/335M [00:01<00:05, 51.0MB/s]
# Downloading:  12% 41.5M/335M [00:01<00:04, 58.7MB/s]
# Downloading:  15% 49.2M/335M [00:01<00:04, 64.0MB/s]
# Downloading:  17% 56.9M/335M [00:01<00:04, 68.1MB/s]
# Downloading:  19% 64.8M/335M [00:01<00:03, 71.3MB/s]
# Downloading:  21% 71.9M/335M [00:01<00:03, 71.3MB/s]
# Downloading:  24% 79.7M/335M [00:01<00:03, 73.3MB/s]
# Downloading:  26% 87.6M/335M [00:02<00:03, 74.9MB/s]
# Downloading:  28% 95.3M/335M [00:02<00:03, 75.6MB/s]
# Downloading:  31% 103M/335M [00:02<00:03, 75.5MB/s]
# Downloading:  33% 110M/335M [00:02<00:02, 75.5MB/s]
# Downloading:  35% 118M/335M [00:02<00:02, 75.4MB/s]
# Downloading:  38% 126M/335M [00:02<00:02, 75.6MB/s]
# Downloading:  40% 133M/335M [00:02<00:02, 76.4MB/s]
# Downloading:  42% 141M/335M [00:02<00:02, 76.2MB/s]
# Downloading:  44% 149M/335M [00:02<00:02, 75.8MB/s]
# Downloading:  47% 156M/335M [00:02<00:02, 75.5MB/s]
# Downloading:  49% 164M/335M [00:03<00:02, 73.8MB/s]
# Downloading:  51% 171M/335M [00:03<00:02, 74.3MB/s]
# Downloading:  53% 179M/335M [00:03<00:02, 75.0MB/s]
# Downloading:  56% 187M/335M [00:03<00:01, 75.6MB/s]
# Downloading:  58% 194M/335M [00:03<00:01, 76.2MB/s]
# Downloading:  60% 202M/335M [00:03<00:01, 76.1MB/s]
# Downloading:  63% 210M/335M [00:03<00:01, 76.8MB/s]
# Downloading:  65% 218M/335M [00:03<00:01, 77.0MB/s]
# Downloading:  67% 225M/335M [00:03<00:01, 75.9MB/s]
# Downloading:  70% 233M/335M [00:03<00:01, 73.2MB/s]
# Downloading:  72% 240M/335M [00:04<00:01, 73.6MB/s]
# Downloading:  74% 248M/335M [00:04<00:01, 74.2MB/s]
# Downloading:  76% 256M/335M [00:04<00:01, 75.0MB/s]
# Downloading:  79% 264M/335M [00:04<00:00, 76.2MB/s]
# Downloading:  81% 271M/335M [00:04<00:00, 76.8MB/s]
# Downloading:  83% 279M/335M [00:04<00:00, 76.4MB/s]
# Downloading:  86% 287M/335M [00:04<00:00, 76.4MB/s]
# Downloading:  88% 294M/335M [00:04<00:00, 75.8MB/s]
# Downloading:  90% 302M/335M [00:04<00:00, 74.9MB/s]
# Downloading:  93% 310M/335M [00:04<00:00, 75.8MB/s]
# Downloading:  95% 318M/335M [00:05<00:00, 76.5MB/s]
# Downloading:  97% 325M/335M [00:05<00:00, 76.9MB/s]
# Downloading: 100% 335M/335M [00:05<00:00, 63.6MB/s]
#
# Downloading: 100% 547/547 [00:00<00:00, 868kB/s]
#
# Downloading: 100% 543/543 [00:00<00:00, 821kB/s]
#
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
#
# Downloading: 100% 342/342 [00:00<00:00, 588kB/s]
#
# Fetching 16 files:   6% 1/16 [00:00<00:03,  4.92it/s]
#
# Downloading: 100% 4.63k/4.63k [00:00<00:00, 6.47MB/s]
#
# Fetching 16 files:  19% 3/16 [00:00<00:01,  7.87it/s]
#
# Downloading:   0% 0.00/608M [00:00<?, ?B/s]
#
# Downloading:   0% 507k/608M [00:00<02:00, 5.03MB/s]
#
# Downloading:   0% 1.29M/608M [00:00<01:30, 6.68MB/s]
#
# Downloading:   0% 2.29M/608M [00:00<01:14, 8.18MB/s]
#
# Downloading:   1% 3.58M/608M [00:00<01:00, 10.0MB/s]
#
# Downloading:   1% 5.21M/608M [00:00<00:49, 12.3MB/s]
#
# Downloading:   1% 7.37M/608M [00:00<00:38, 15.4MB/s]
#
# Downloading:   2% 10.1M/608M [00:00<00:31, 19.3MB/s]
#
# Downloading:   2% 13.5M/608M [00:00<00:24, 24.1MB/s]
#
# Downloading:   3% 18.0M/608M [00:00<00:19, 30.4MB/s]
#
# Downloading:   4% 23.7M/608M [00:01<00:15, 38.7MB/s]
#
# Downloading:   5% 30.0M/608M [00:01<00:12, 46.2MB/s]
#
# Downloading:   6% 38.2M/608M [00:01<00:09, 57.0MB/s]
#
# Downloading:   8% 46.6M/608M [00:01<00:08, 65.1MB/s]
#
# Downloading:   9% 54.9M/608M [00:01<00:07, 70.7MB/s]
#
# Downloading:  10% 63.3M/608M [00:01<00:07, 74.6MB/s]
#
# Downloading:  12% 71.8M/608M [00:01<00:06, 77.6MB/s]
#
# Downloading:  13% 80.1M/608M [00:01<00:06, 79.4MB/s]
#
# Downloading:  15% 88.6M/608M [00:01<00:06, 80.9MB/s]
#
# Downloading:  16% 96.9M/608M [00:01<00:06, 81.7MB/s]
#
# Downloading:  17% 105M/608M [00:02<00:06, 82.8MB/s]
#
# Downloading:  19% 114M/608M [00:02<00:05, 82.7MB/s]
#
# Downloading:  20% 122M/608M [00:02<00:05, 83.2MB/s]
#
# Downloading:  21% 131M/608M [00:02<00:05, 81.2MB/s]
#
# Downloading:  23% 139M/608M [00:02<00:05, 82.2MB/s]
#
# Downloading:  24% 147M/608M [00:02<00:05, 80.3MB/s]
#
# Downloading:  26% 155M/608M [00:02<00:05, 80.5MB/s]
#
# Downloading:  27% 164M/608M [00:02<00:05, 81.3MB/s]
#
# Downloading:  28% 172M/608M [00:02<00:05, 82.0MB/s]
#
# Downloading:  30% 180M/608M [00:02<00:05, 81.6MB/s]
#
# Downloading:  31% 189M/608M [00:03<00:05, 82.3MB/s]
#
# Downloading:  32% 197M/608M [00:03<00:04, 82.3MB/s]
#
# Downloading:  34% 205M/608M [00:03<00:04, 82.8MB/s]
#
# Downloading:  35% 214M/608M [00:03<00:04, 83.2MB/s]
#
# Downloading:  37% 222M/608M [00:03<00:04, 82.3MB/s]
#
# Downloading:  38% 230M/608M [00:03<00:04, 82.8MB/s]
#
# Downloading:  39% 239M/608M [00:03<00:04, 83.4MB/s]
#
# Downloading:  41% 247M/608M [00:03<00:04, 83.8MB/s]
#
# Downloading:  42% 256M/608M [00:03<00:04, 84.4MB/s]
#
# Downloading:  43% 264M/608M [00:03<00:04, 84.2MB/s]
#
# Downloading:  45% 273M/608M [00:04<00:03, 84.7MB/s]
#
# Downloading:  46% 281M/608M [00:04<00:03, 82.7MB/s]
#
# Downloading:  48% 290M/608M [00:04<00:03, 82.5MB/s]
#
# Downloading:  49% 298M/608M [00:04<00:03, 83.3MB/s]
#
# Downloading:  50% 306M/608M [00:04<00:03, 82.0MB/s]
#
# Downloading:  52% 315M/608M [00:04<00:03, 82.7MB/s]
#
# Downloading:  53% 323M/608M [00:04<00:03, 83.4MB/s]
#
# Downloading:  55% 332M/608M [00:04<00:03, 83.7MB/s]
#
# Downloading:  56% 340M/608M [00:04<00:03, 84.3MB/s]
#
# Downloading:  57% 349M/608M [00:04<00:03, 84.8MB/s]
#
# Downloading:  59% 358M/608M [00:05<00:02, 84.8MB/s]
#
# Downloading:  60% 366M/608M [00:05<00:02, 83.9MB/s]
#
# Downloading:  62% 375M/608M [00:05<00:02, 84.5MB/s]
#
# Downloading:  63% 383M/608M [00:05<00:02, 84.4MB/s]
#
# Downloading:  64% 392M/608M [00:05<00:02, 84.8MB/s]
#
# Downloading:  66% 400M/608M [00:05<00:02, 84.7MB/s]
#
# Downloading:  67% 409M/608M [00:05<00:02, 84.7MB/s]
#
# Downloading:  69% 417M/608M [00:05<00:02, 84.5MB/s]
#
# Downloading:  70% 426M/608M [00:05<00:02, 84.9MB/s]
#
# Downloading:  71% 434M/608M [00:05<00:02, 82.8MB/s]
#
# Downloading:  73% 442M/608M [00:06<00:01, 82.9MB/s]
#
# Downloading:  74% 451M/608M [00:06<00:01, 82.3MB/s]
#
# Downloading:  76% 459M/608M [00:06<00:01, 82.9MB/s]
#
# Downloading:  77% 468M/608M [00:06<00:01, 82.6MB/s]
#
# Downloading:  78% 476M/608M [00:06<00:01, 83.4MB/s]
#
# Downloading:  80% 485M/608M [00:06<00:01, 83.9MB/s]
#
# Downloading:  81% 493M/608M [00:06<00:01, 83.8MB/s]
#
# Downloading:  82% 501M/608M [00:06<00:01, 84.3MB/s]
#
# Downloading:  84% 510M/608M [00:06<00:01, 84.3MB/s]
#
# Downloading:  85% 518M/608M [00:06<00:01, 84.0MB/s]
#
# Downloading:  87% 527M/608M [00:07<00:00, 84.2MB/s]
#
# Downloading:  88% 535M/608M [00:07<00:00, 84.3MB/s]
#
# Downloading:  89% 544M/608M [00:07<00:00, 84.4MB/s]
#
# Downloading:  91% 552M/608M [00:07<00:00, 84.4MB/s]
#
# Downloading:  92% 561M/608M [00:07<00:00, 83.9MB/s]
#
# Downloading:  94% 569M/608M [00:07<00:00, 78.5MB/s]
#
# Downloading:  95% 577M/608M [00:07<00:00, 76.8MB/s]
#
# Downloading:  96% 585M/608M [00:07<00:00, 75.6MB/s]
#
# Downloading:  97% 592M/608M [00:07<00:00, 75.7MB/s]
#
# Downloading:  99% 600M/608M [00:08<00:00, 75.0MB/s]
#
# Downloading: 100% 608M/608M [00:08<00:00, 75.0MB/s]
#
# Fetching 16 files:  25% 4/16 [00:08<00:35,  2.95s/it]
#
# Downloading: 100% 209/209 [00:00<00:00, 276kB/s]
#
# Fetching 16 files:  31% 5/16 [00:08<00:22,  2.04s/it]
#
# Downloading: 100% 209/209 [00:00<00:00, 208kB/s]
#
# Fetching 16 files:  38% 6/16 [00:09<00:14,  1.46s/it]
#
# Downloading: 100% 572/572 [00:00<00:00, 882kB/s]
#
# Fetching 16 files:  44% 7/16 [00:09<00:09,  1.06s/it]
#
# Downloading:   0% 0.00/246M [00:00<?, ?B/s]
#
# Downloading:   0% 736k/246M [00:00<00:33, 7.27MB/s]
#
# Downloading:   1% 2.09M/246M [00:00<00:22, 10.9MB/s]
#
# Downloading:   2% 3.82M/246M [00:00<00:17, 13.8MB/s]
#
# Downloading:   2% 6.01M/246M [00:00<00:14, 17.0MB/s]
#
# Downloading:   4% 8.84M/246M [00:00<00:11, 21.1MB/s]
#
# Downloading:   5% 12.4M/246M [00:00<00:08, 26.2MB/s]
#
# Downloading:   7% 17.1M/246M [00:00<00:07, 32.7MB/s]
#
# Downloading:   9% 23.0M/246M [00:00<00:05, 41.0MB/s]
#
# Downloading:  12% 30.3M/246M [00:00<00:04, 51.1MB/s]
#
# Downloading:  15% 38.0M/246M [00:01<00:03, 59.0MB/s]
#
# Downloading:  19% 46.1M/246M [00:01<00:03, 65.9MB/s]
#
# Downloading:  22% 53.7M/246M [00:01<00:02, 68.9MB/s]
#
# Downloading:  25% 61.2M/246M [00:01<00:02, 70.7MB/s]
#
# Downloading:  28% 68.2M/246M [00:01<00:02, 69.9MB/s]
#
# Downloading:  31% 75.6M/246M [00:01<00:02, 70.9MB/s]
#
# Downloading:  34% 82.7M/246M [00:01<00:02, 70.6MB/s]
#
# Downloading:  36% 89.7M/246M [00:01<00:02, 69.8MB/s]
#
# Downloading:  39% 96.7M/246M [00:01<00:02, 66.0MB/s]
#
# Downloading:  42% 104M/246M [00:01<00:02, 69.2MB/s]
#
# Downloading:  46% 112M/246M [00:02<00:01, 71.4MB/s]
#
# Downloading:  49% 120M/246M [00:02<00:01, 72.7MB/s]
#
# Downloading:  52% 127M/246M [00:02<00:01, 73.4MB/s]
#
# Downloading:  55% 135M/246M [00:02<00:01, 73.0MB/s]
#
# Downloading:  58% 142M/246M [00:02<00:01, 73.3MB/s]
#
# Downloading:  61% 150M/246M [00:02<00:01, 74.3MB/s]
#
# Downloading:  64% 157M/246M [00:02<00:01, 72.3MB/s]
#
# Downloading:  67% 164M/246M [00:02<00:01, 68.8MB/s]
#
# Downloading:  70% 172M/246M [00:02<00:01, 71.0MB/s]
#
# Downloading:  73% 179M/246M [00:02<00:00, 72.2MB/s]
#
# Downloading:  76% 187M/246M [00:03<00:00, 73.1MB/s]
#
# Downloading:  79% 194M/246M [00:03<00:00, 72.2MB/s]
#
# Downloading:  82% 202M/246M [00:03<00:00, 74.6MB/s]
#
# Downloading:  85% 210M/246M [00:03<00:00, 76.1MB/s]
#
# Downloading:  89% 218M/246M [00:03<00:00, 77.6MB/s]
#
# Downloading:  92% 226M/246M [00:03<00:00, 76.5MB/s]
#
# Downloading:  95% 234M/246M [00:03<00:00, 77.3MB/s]
#
# Downloading: 100% 246M/246M [00:03<00:00, 64.5MB/s]
#
# Fetching 16 files:  50% 8/16 [00:13<00:15,  1.97s/it]
#
# Downloading: 100% 525k/525k [00:00<00:00, 5.62MB/s]
#
# Fetching 16 files:  56% 9/16 [00:13<00:10,  1.46s/it]
#
# Downloading: 100% 472/472 [00:00<00:00, 620kB/s]
#
# Fetching 16 files:  62% 10/16 [00:13<00:06,  1.07s/it]
#
# Downloading: 100% 788/788 [00:00<00:00, 1.30MB/s]
#
# Fetching 16 files:  69% 11/16 [00:14<00:04,  1.23it/s]
#
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading: 100% 1.06M/1.06M [00:00<00:00, 7.98MB/s]
#
# Fetching 16 files: 100% 16/16 [00:14<00:00,  1.11it/s]
# /usr/local/lib/python3.7/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:12<00:38, 12.86s/it]
# Generating samples:  50% 2/4 [00:21<00:21, 10.67s/it]
# Generating samples:  75% 3/4 [00:31<00:10, 10.04s/it]
# Generating samples: 100% 4/4 [00:40<00:00, 10.16s/it]
# [*] Weights saved at /content/drive/MyDrive/AI_5/Stable_diffusion/akshay_model/Output/weights/4000
# Steps: 100% 4000/4000 [1:06:22<00:00,  1.00it/s, loss=0.269, lr=1e-6]

# %% [markdown]
# ## Inference

# %%
WEIGHTS_DIR = "/content/drive/MyDrive/AI_5/Stable_diffusion/akshay_model/Output/weights/4000" # pass this empty if you need to get a new model
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/AI_5/Stable_diffusion/akshay_model/Output/weights/4000

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)
pipe = StableDiffusionPipeline.from_pretrained(model_path, scheduler=scheduler, safety_checker=None, torch_dtype=torch.float16).to("cuda")

g_cuda = None
# Out:
# /usr/local/lib/python3.7/dist-packages/diffusers/utils/deprecation_utils.py:35: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.9.0",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "clip_sample": false,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "set_alpha_to_one": false,
#   "steps_offset": 0,
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   warnings.warn(warning + message, FutureWarning)

# %% [markdown]
# akshay person as a king on throne, 4 k post processing, unreal engine, aesthetic!!!!!!!, intricate, ultra detailed, artstation style

# %% [markdown]
# god of fortune 4 k post processing, unreal engine, aesthetic!!!!!!!, intricate, ultra detailed, artstation style

# %% [markdown]
# Akshay person holding golden apple, 4 k post processing, unreal engine, aesthetic!!!!!!!, intricate, ultra detailed, artstation style

# %%
#@title Run for generating images.

prompt = "Visibly sad crying akshay person, 4 k post processing, unreal engine, aesthetic!!!!!!!, intricate, ultra detailed, artstation style" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 4.7 #@param {type:"number"}
num_inference_steps = 60 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9F64F1810>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9F64F1F90>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9F64F1510>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9F64F1BD0>
